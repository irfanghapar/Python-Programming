# %% [markdown]
# <a href="https://colab.research.google.com/github/irfanghapar/Python-Programming/blob/main/Using_Python_as_Calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Irfan Ghapar
# 3.1 Using Python as Calculator
# 3.1.1 Numbers

2 + 2

50 - 5 * 6

(50 - 5 * 6) / 4

8 / 5

# divisions always return a floating point number

17 / 3

17 // 3

17 % 3

5 * 3 + 2

# // will ignore the fractional result
# % give us the remainder

5 ** 2

2 ** 7

# ** means squared

width = 20

height = 5 * 9

width * height

# = used to assign variable

n

# try to access an undefined variable

4 * 3.75 - 1

# Will end with floating point

tax = 12.5 / 100
price = 100.50
price * tax
price + _
round(_, 2)

# Last printed session will be assigned to variable "_"

# 3.12 Strings

'spam eggs'  # single quotes
'spam eggs'
'doesn\'t'  # use \' to escape the single quote...
"doesn't"
"doesn't"  # ...or use double quotes instead
"doesn't"
'"Yes," they said.'
"\"Yes,\" they said."

# Python also can manipulate strings. \ can be use to escape quote

'"Isn\'t," they said.'
# '"Isn\'t," they said.'
print('"Isn\'t," they said.')
# "Isn't," they said.
s = 'First line.\nSecond line.'  # \n means newline
s  # without print(), \n is included in the output
# 'First line.\nSecond line.'
print(s)  # with print(), \n produces a new line
# First line.
# Second line.

# print function produces more readable output

print('C:\some\name')  # here \n means newline!
# C:\some
# ame
print(r'C:\some\name')  # note the r before the quote
# C:\some\name

# Can use raw strings by adding r before the first quote

print("""\
Usage: thingy [OPTIONS]
     -h                        Display this usage message
     -H hostname               Hostname to connect to
""")

# String can span multiple lines by using triple quotes

# 3 times 'un', followed by 'ium'
3 * 'un' + 'ium'
# 'unununium'

# Strings can be concatenated with the + operator and repeated *

'Py' 'thon'
# 'Python'

# Two or more string literals next to each other are automatically concatenated
# This feature is good if we want to joined them together

prefix = 'Py'
prefix 'thon'  # can't concatenate a variable and a string literal
# File "<stdin>", line 1
# prefix 'thon'
#             ^
# SyntaxError: invalid syntax

('un' * 3) 'ium'
# File "<stdin>", line 1
#    ('un' * 3) 'ium'
#                   ^
# SyntaxError: invalid syntax

# This only works with two literals, not with variable expressions

prefix + 'thon'
# 'Python'

# Use + if want to concatenate

word = 'Python'
word[0]  # character in position 0
'P'
word[5]  # character in position 5
'n'

word[-2]  # second-last character
'o'
word[-6]
'P'

# Strings can be indexed
# Indices can also be negative number
# -0 is same as 0, negative indices start from -1

word[0:2]
# 'Py'
word[2:5]
#'tho'
word[:2] + word[2:]
# 'Python'
word[:4] + word[4:]
# 'Python'
word[:2]   # character from the beginning to position 2 (excluded)
#'Py'
word[4:]   # characters from position 4 (included) to the end
#'on'
wword[-2:]  # characters from the second-last (included) to the end
#'on'

# Slicing is also supported. Slicing allows us to obtain substring
# Noted how start is always included and end always excluded. Ensure s[:i] + s[i:] = s

word[0] = 'J'
# Traceback (most recent call last):
#   File "<stdin>", line 1, in <module>
# TypeError: 'str' object does not support item assignment
word[2:] = 'py'
# Traceback (most recent call last):
#  File "<stdin>", line 1, in <module>
# TypeError: 'str' object does not support item assignment

# Python strings cannot be changed
# If need different string please create new one

s = 'irfannoobieskubis'
len(s)

# len will return the length of string


# 3.1.3 List

squares = [1, 4, 9, 16, 25]
squares
# [1, 4, 9, 16, 25]

squares[0]  # indexing returns the item
#1
squares[-1]
#25
squares[-3:]  # slicing returns a new list
# [9, 16, 25]

# List can be indexed and sliced

squares[:]
# [1, 4, 9, 16, 25]

# Return a new list containing requested elements

squares + [36, 49, 64, 81, 100]
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# List support concatenation

cubes = [1, 8, 27, 65, 125]  # something's wrong here
4 ** 3  # the cube of 4 is 64, not 65!
# 64
cubes[3] = 64  # replace the wrong value
cubes
# [1, 8, 27, 64, 125]

# Using append will add new items at the end of the list

letters = ['a', 'b', 'c', 'd', 'e', 'f', 'g']
letters
# ['a', 'b', 'c', 'd', 'e', 'f', 'g']
# replace some values
letters[2:5] = ['C', 'D', 'E']
letters
# ['a', 'b', 'C', 'D', 'E', 'f', 'g']
# now remove them
letters[2:5] = []
letters
# ['a', 'b', 'f', 'g']
# clear the list by replacing all the elements with an empty list
letters[:] = []
letters
# []

# It also can change the size of the list entirely

letters = ['a', 'b', 'c', 'd']
len(letters)
# 4

# len also applies to list

a = ['a', 'b', 'c']
n = [1, 2, 3]
x = [a, n]
x
# [['a', 'b', 'c'], [1, 2, 3]]
x[0]
# ['a', 'b', 'c']
x[0][1]
# 'b'

# We also can create list containing other list
# Out:
# 128
